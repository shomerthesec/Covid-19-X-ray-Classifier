# %%
# connecting to drive to get the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install patool
# Out:
# Collecting patool
#   Downloading https://files.pythonhosted.org/packages/43/94/52243ddff508780dd2d8110964320ab4851134a55ab102285b46e740f76a/patool-1.12-py2.py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 3.9MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
# importing important libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import patoolib

patoolib.extract_archive('/content/drive/My Drive/X-ray.rar', outdir="/")
# Out:
# patool: Extracting /content/drive/My Drive/X-ray.rar ...
# patool: running /usr/bin/unrar x -- "/content/drive/My Drive/X-ray.rar"
# patool:     with cwd='/'
# patool: ... /content/drive/My Drive/X-ray.rar extracted to `/'.
# '/'

# %%
import os
covid_dir = os.path.join('/X-ray/COVID')
normal_dir = os.path.join('/X-ray/NORMAL')
pneumonia_dir = os.path.join('/X-ray/PNEUMONIA')

print('total training covid images:', len(os.listdir(covid_dir)))
print('total training normal images:', len(os.listdir(normal_dir)))
print('total training pneumonia images:', len(os.listdir(pneumonia_dir)))

rock_files = os.listdir(covid_dir)
print(rock_files[:10])

paper_files = os.listdir(normal_dir)
print(paper_files[:10])

scissors_files = os.listdir(pneumonia_dir)
print(scissors_files[:10])
# Out:
# total training covid images: 4044
# total training normal images: 3941
# total training pneumonia images: 4273
# ['aug_31BA3780-2323-493F-8AED-62081B9C383B._PL_4.jpg', 'person1612_virus_2797.jpeg', '90070cbc.jpg', 'person491_virus_997.jpeg', '046.jpeg', 'person1504_virus_2614.jpeg', 'COVID-19 (103).png', 'AR-1.jpg', 'person441_virus_895.jpeg', 'aug_F63AB6CE-1968-4154-A70F-913AF154F53D._avg_1.jpg']
# ['00002032_006.png', '00003097_003.png', 'NORMAL2-IM-1150-0001.jpeg', '00003248_001.png', 'NORMAL2-IM-0525-0001.jpeg', 'Non-COVID-19 (76).jpg', 'Non-COVID-19 (236).jpeg', 'Non-COVID-19 (182).jpg', '00002860_002.png', 'NORMAL2-IM-0836-0001.jpeg']
# ['person1439_bacteria_3722.jpeg', 'person1612_virus_2797.jpeg', 'person139_bacteria_663.jpeg', 'person491_virus_997.jpeg', 'person1504_virus_2614.jpeg', 'person441_virus_895.jpeg', 'person51_bacteria_244.jpeg', 'person1030_virus_1722.jpeg', 'person1040_virus_1735.jpeg', 'person514_virus_1031.jpeg']

# %%
# %matplotlib inline
import matplotlib.image as mpimg

pic_index = 2

next_rock = [os.path.join(covid_dir, fname) 
                for fname in rock_files[pic_index-2:pic_index]]
                
next_paper = [os.path.join(normal_dir, fname) 
                for fname in paper_files[pic_index-2:pic_index]]

next_scissors = [os.path.join(pneumonia_dir, fname) 
                for fname in scissors_files[pic_index-2:pic_index]]

for i, img_path in enumerate(next_rock+next_paper+next_scissors):
  #print(img_path)
  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.axis('Off')
  plt.show()

# %%
# Loading the data from the directory of train and test

TRAINING_DIR = '/X-ray/' 
train_datagen = ImageDataGenerator( rescale=1.0/255, samplewise_center=True,  samplewise_std_normalization= True) 


# TRAIN GENERATOR.
train_generator = train_datagen.flow_from_directory(
                                              TRAINING_DIR , target_size=(224, 224),  
                                              batch_size=126,
                                              class_mode='categorical') 



VALIDATION_DIR = "/content/drive/My Drive/datasets/train/"
validation_datagen = ImageDataGenerator(rescale=1.0/255, samplewise_center=True,  samplewise_std_normalization= True)


validation_generator = validation_datagen.flow_from_directory(
	VALIDATION_DIR,
	target_size=(224,224),
	class_mode='categorical',
  batch_size=126
)



TEST_DIR = '/content/drive/My Drive/datasets/test/' 
test_datagen = ImageDataGenerator( rescale=1.0/255, samplewise_center=True,  samplewise_std_normalization= True ) 


# TEST GENERATOR.
test_generator = test_datagen.flow_from_directory(
                                              TEST_DIR , target_size=(224, 224),
                                              class_mode='categorical')
# Out:
# Found 12251 images belonging to 3 classes.
# Found 270 images belonging to 3 classes.
# Found 326 images belonging to 3 classes.

# %%
# to visualize the data in the generators

x_batch, y_batch = next(train_generator) 
for i in range (0,10):
    image = x_batch[i]
    plt.imshow(image)

    if y_batch[i][0] == 1: print('folder= covid')
    elif y_batch[i][1] == 1: print('folder= normal')
    elif y_batch[i][2] == 1: print('folder= pnuemenia')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= normal
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# folder= pnuemenia

# %%
from tensorflow.keras.applications.vgg19 import VGG19
pre_trained_model = VGG19(input_shape = (224, 224 , 3), include_top = False , pooling='avg' , weights = 'imagenet' )
pre_trained_model.trainable = False

# %%
model=tf.keras.Sequential([
                           pre_trained_model,
                           tf.keras.layers.Dense( 1028, activation='relu') ,
                           tf.keras.layers.Dropout(0.3) ,
                           tf.keras.layers.BatchNormalization(),
                           tf.keras.layers.Dense( 1028, activation='relu') ,
                           tf.keras.layers.Dropout(0.3) ,
                           tf.keras.layers.BatchNormalization(),
                           tf.keras.layers.Dense( 1028, activation='relu') ,
                           tf.keras.layers.Dropout(0.3) ,
                           tf.keras.layers.Dense(3,  activation='softmax')
])

#opt=tf.keras.optimizers.RMSprop( 0.001 , momentum=0.9)
#opt=tf.keras.optimizers.SGD( 0.001,0.9 )
model.compile(optimizer='adam' , loss = 'categorical_crossentropy',  metrics = ['accuracy'] )

model.summary()
cb=tf.keras.callbacks.ModelCheckpoint(
                                      f'checkpoint_test' , monitor='val_loss', verbose=0, save_best_only=True,
                                      save_weights_only=False, mode='auto', save_freq='epoch' )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 512)               20024384
# _________________________________________________________________
# dense_4 (Dense)              (None, 1028)              527364
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1028)              4112
# _________________________________________________________________
# dense_5 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1028)              4112
# _________________________________________________________________
# dense_6 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 3087
# =================================================================
# Total params: 22,678,683
# Trainable params: 2,650,187
# Non-trainable params: 20,028,496
# _________________________________________________________________

# %%
history = model.fit(train_generator, validation_data= validation_generator ,
                    epochs = 25, shuffle=True, workers=-1,
                    verbose = 1,callbacks=cb)
'''history = model.fit(
              x=None, y=None, batch_size=None, epochs=1, verbose=1, callbacks=None,
                  validation_split=0.0, validation_data=None, shuffle=True, class_weight=None,
                  sample_weight=None, initial_epoch=0, steps_per_epoch=None,
                  validation_steps=None, validation_batch_size=None, validation_freq=1,
                  max_queue_size=10, workers=1, use_multiprocessing=False )'''
# Out:
# Epoch 1/25
# 98/98 [==============================] - ETA: 0s - loss: 0.8386 - accuracy: 0.6880INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 223s 2s/step - loss: 0.8386 - accuracy: 0.6880 - val_loss: 0.7831 - val_accuracy: 0.8148
# Epoch 2/25
# 98/98 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.7517INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 222s 2s/step - loss: 0.6262 - accuracy: 0.7517 - val_loss: 0.6813 - val_accuracy: 0.8556
# Epoch 3/25
# 98/98 [==============================] - ETA: 0s - loss: 0.5574 - accuracy: 0.7643INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 222s 2s/step - loss: 0.5574 - accuracy: 0.7643 - val_loss: 0.6483 - val_accuracy: 0.6667
# Epoch 4/25
# 98/98 [==============================] - ETA: 0s - loss: 0.5172 - accuracy: 0.7839INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 225s 2s/step - loss: 0.5172 - accuracy: 0.7839 - val_loss: 0.3575 - val_accuracy: 0.9259
# Epoch 5/25
# 98/98 [==============================] - 224s 2s/step - loss: 0.5237 - accuracy: 0.7835 - val_loss: 0.6182 - val_accuracy: 0.6630
# Epoch 6/25
# 98/98 [==============================] - 223s 2s/step - loss: 0.5319 - accuracy: 0.7762 - val_loss: 0.4284 - val_accuracy: 0.8963
# Epoch 7/25
# 98/98 [==============================] - 220s 2s/step - loss: 0.5326 - accuracy: 0.7786 - val_loss: 0.8067 - val_accuracy: 0.5630
# Epoch 8/25
# 98/98 [==============================] - 219s 2s/step - loss: 0.5155 - accuracy: 0.7834 - val_loss: 0.4670 - val_accuracy: 0.8407
# Epoch 9/25
# 98/98 [==============================] - 218s 2s/step - loss: 0.4981 - accuracy: 0.7907 - val_loss: 0.6022 - val_accuracy: 0.7630
# Epoch 10/25
# 98/98 [==============================] - 219s 2s/step - loss: 0.5008 - accuracy: 0.7950 - val_loss: 0.6281 - val_accuracy: 0.7481
# Epoch 11/25
# 98/98 [==============================] - 219s 2s/step - loss: 0.4958 - accuracy: 0.7928 - val_loss: 0.4927 - val_accuracy: 0.8222
# Epoch 12/25
# 98/98 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.7932INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 220s 2s/step - loss: 0.4916 - accuracy: 0.7932 - val_loss: 0.3188 - val_accuracy: 0.9222
# Epoch 13/25
# 98/98 [==============================] - ETA: 0s - loss: 0.5028 - accuracy: 0.7889INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 222s 2s/step - loss: 0.5028 - accuracy: 0.7889 - val_loss: 0.2844 - val_accuracy: 0.9222
# Epoch 14/25
# 98/98 [==============================] - 220s 2s/step - loss: 0.4847 - accuracy: 0.8012 - val_loss: 0.4021 - val_accuracy: 0.8630
# Epoch 15/25
# 98/98 [==============================] - 221s 2s/step - loss: 0.4671 - accuracy: 0.8009 - val_loss: 0.3057 - val_accuracy: 0.9222
# Epoch 16/25
# 98/98 [==============================] - 221s 2s/step - loss: 0.4722 - accuracy: 0.7980 - val_loss: 0.3592 - val_accuracy: 0.9111
# Epoch 17/25
# 98/98 [==============================] - 222s 2s/step - loss: 0.4609 - accuracy: 0.8029 - val_loss: 0.2844 - val_accuracy: 0.9259
# Epoch 18/25
# 98/98 [==============================] - 222s 2s/step - loss: 0.4544 - accuracy: 0.8090 - val_loss: 0.2885 - val_accuracy: 0.9333
# Epoch 19/25
# 98/98 [==============================] - 222s 2s/step - loss: 0.4488 - accuracy: 0.8117 - val_loss: 0.3462 - val_accuracy: 0.8926
# Epoch 20/25
# 98/98 [==============================] - 222s 2s/step - loss: 0.4438 - accuracy: 0.8124 - val_loss: 0.2985 - val_accuracy: 0.9259
# Epoch 21/25
# 98/98 [==============================] - 221s 2s/step - loss: 0.4354 - accuracy: 0.8136 - val_loss: 0.3023 - val_accuracy: 0.9296
# Epoch 22/25
# 98/98 [==============================] - 222s 2s/step - loss: 0.4352 - accuracy: 0.8153 - val_loss: 0.3113 - val_accuracy: 0.8926
# Epoch 23/25
# 98/98 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.8155INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 226s 2s/step - loss: 0.4348 - accuracy: 0.8155 - val_loss: 0.2785 - val_accuracy: 0.9481
# Epoch 24/25
# 98/98 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.8207INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 227s 2s/step - loss: 0.4225 - accuracy: 0.8207 - val_loss: 0.2635 - val_accuracy: 0.9296
# Epoch 25/25
# 98/98 [==============================] - ETA: 0s - loss: 0.4277 - accuracy: 0.8170INFO:tensorflow:Assets written to: checkpoint_test/assets
# 98/98 [==============================] - 227s 2s/step - loss: 0.4277 - accuracy: 0.8170 - val_loss: 0.2634 - val_accuracy: 0.9481
# 'history = model.fit(\n              x=None, y=None, batch_size=None, epochs=1, verbose=1, callbacks=None,\n                  validation_split=0.0, validation_data=None, shuffle=True, class_weight=None,\n                  sample_weight=None, initial_epoch=0, steps_per_epoch=None,\n                  validation_steps=None, validation_batch_size=None, validation_freq=1,\n                  max_queue_size=10, workers=1, use_multiprocessing=False )'

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()


plt.show()

# %%
export_dir='model_VGG_Adam_normalized_images'
tf.saved_model.save( model , export_dir)
# Out:
# INFO:tensorflow:Assets written to: model_VGG_Adam_normalized_images/assets

# %%
# !zip -r model_VGG_Adam_normalized_images.zip 'model_VGG_Adam_normalized_images'
#Download files
from google.colab import files 
files.download('model_VGG_Adam_normalized_images.zip')
# Out:
#   adding: model_VGG_Adam_normalized_images/ (stored 0%)
#   adding: model_VGG_Adam_normalized_images/saved_model.pb (deflated 91%)
#   adding: model_VGG_Adam_normalized_images/variables/ (stored 0%)
#   adding: model_VGG_Adam_normalized_images/variables/variables.data-00000-of-00002 (deflated 82%)
#   adding: model_VGG_Adam_normalized_images/variables/variables.data-00001-of-00002 (deflated 9%)
#   adding: model_VGG_Adam_normalized_images/variables/variables.index (deflated 71%)
#   adding: model_VGG_Adam_normalized_images/assets/ (stored 0%)

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
history=tf.keras.models.load_model('model_VGG_Adam_normalized_images')

# %%
history.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 512)               20024384
# _________________________________________________________________
# dense_4 (Dense)              (None, 1028)              527364
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1028)              4112
# _________________________________________________________________
# dense_5 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1028)              4112
# _________________________________________________________________
# dense_6 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 3087
# =================================================================
# Total params: 22,678,683
# Trainable params: 22,674,571
# Non-trainable params: 4,112
# _________________________________________________________________

# %%
# making predictions on images the model was not trained on

# to visualize the data in the generators
predicted_label = np.argmax(history.predict( test_generator ),axis=1)
labels={0:'Covid' , 1:'Normal' , 2:'Pnumenia'}
pred= [labels[x] for x in predicted_label]

x_batch, y_batch = next(test_generator) 
for i in range (0,10):
    image = x_batch[i]
    plt.imshow(image)
    print('prediction =', pred[i])
    if y_batch[i][0] == 1: print('folder= covid')
    elif y_batch[i][1] == 1: print('folder= normal')
    elif y_batch[i][2] == 1: print('folder= pnuemenia')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Covid
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Pnumenia
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Pnumenia
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Pnumenia
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Normal
# folder= normal
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Pnumenia
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Covid
# folder= pnuemenia
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Covid
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Pnumenia
# folder= covid
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# prediction = Normal
# folder= covid

# %%
# making predictions on images the model was not trained on

test = '../test_images/' # directory of test images

test_datagen = ImageDataGenerator( rescale=1.0/255 )  # preparing the test data as we done with train and valdiation

test_generator = test_datagen.flow_from_directory(
                                              test , target_size=(224, 224),
                                              class_mode='categorical',shuffle=False)  
# to visualize the data in the generators
labels={0:'Covid' , 1:'Normal' , 2:'Pnumenia'}
# then feed the variable images into the predict func.
predicted_label = np.argmax(history.predict( test_generator ),axis=1)
pred= [labels[x] for x in predicted_label]

x_batch, y_batch = next(test_generator) 
for i in range (len(pred)):
    image = x_batch[i]
    plt.imshow(image)
    print('prediction =', pred[i])
    if y_batch[i][0] == 1: print('folder= covid')
    elif y_batch[i][1] == 1: print('folder= normal')
    #elif y_batch[i][2] == 1: print('folder= Nawwar')
    elif y_batch[i][2] == 1: print('folder= pnuemenia')
    plt.show()
